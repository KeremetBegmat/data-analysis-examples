# %%
import pandas as pd

# %%
df = pd.read_csv('data/Minjust2018.csv', header=None, usecols=[4, 16,19, 27, 28, 33])

# %%
df.rename(columns={4: 'name', 16: 'adress', 19: 'telephone', 27:'director', 28:'activity', 33:'founders'}, inplace = True)

# %%
df.fillna('', inplace=True)

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
df.loc[df['adress'] == ('Турусбекова')]
# Out:
#                                                      name       adress  \
# 188                  Центр менеджмента и бизнеса при КГНУ  Турусбекова
# 253                                          ОсОО "ЭРДЭМ"  Турусбекова
# 976                                      ОсОО "ПРИМЕВАРА"  Турусбекова
# 1144                                         ОсОО "У & Г"  Турусбекова
# 2702                                         ОсОО "Наас "  Турусбекова
# 6076    Общество с ограниченной ответственностью "Кыды...  Турусбекова
# 9664    Общество с ограниченной ответственностю "ГТРП-...  Турусбекова
# 10034                     Иностранное Турецкое ООО "TARA"  Турусбекова
# 13205                                     ОсОО "ТРИОНИКС"  Турусбекова
# 14407                       ОО "Экологическая инициатива"  Турусбекова
# 15187                                   ОсОО "Первый Рим"  Турусбекова
# 15660   У-е Центр "Магистратуры, аспирантуры и национа...  Турусбекова
# ...

# %%
df.loc[df['director'].str.contains ('Лариса')]
# Out:
#                                                      name              adress  \
# 900     Иностранное американского ОсОО "Центр по изуче...              Гоголя
# 1568        Филиал Закрытого акционерного общества "ДАКО"      ул. Табалдиева
# 1895      Общество с ограниченной ответственностью "ЛаРа"        мкр. "Джал "
# 2310                                     АООТ "Дорсервис"             Полевая
# 3198                                         ОсОО "Ла Ра"        мкр. "Джал "
# 5934        Закрытое акционерное общество "Стройкомплекс"            Промзона
# 6350             Товарищество собственников жилья "Диона"      ул. Логвиненко
# 6737    Учреждение "Петровская музыкальная школа Моско...       ул. Советская
# 8126    Общество с ограниченной ответственностью "ANEL...         ул.Киевская
# 8229    Общество с ограниченной ответственностью "Торг...        Абдрахманова
# 8333         Общественное объединение "Цветик-Семицветик"
# ...

# %%
df.loc[df['adress'] == 'Турусбекова'] [df['director'].str.contains('Лариса')]
# Out:
# C:\Users\BBBB\AppData\Local\conda\conda\envs\myenv\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                name       adress telephone                   director  \
# 30374  ОсОО "Легат"  Турусбекова    663469  Логинова Лариса Сергеевна
#
#       activity                  founders
# 30374           ЛогиноваЛариса Сергеевна

# %%
df.loc[df['director'].str.contains ('Нурбек')]
# Out:
#                                                      name  \
# 1119                                      ОсОО"ЖАНАР ЛТД"
# 1156    Совместное Казахско-Кыргызское ООО "Трилис-Кыр...
# 2950    Совместное Кыргызско-Американское предприятие ...
# 3129                Учреждение "Ибраимовский айыл окмоту"
# 3605    Общество с ограниченной ответственностью  «Нур...
# 3662    ОФ "Общественный благотворительный фонд "ХИДАЯ...
# 3789    Общество с ограниченной ответственностью "Asti...
# 3948    Учреждение "Иссык-кульское районное управление...
# 4151    Общество с ограниченной ответственностью "Микр...
# 4194    Общество с ограниченной ответственнотью  "Атай...
# 4277    Общества с дополнительной ответственностью "Ло...
# 4466    Общество с ограниченной ответственностью  "РАЙ...
# 4808    Общество с ограниченной ответственностью "Ак-Т...
# 4932    Общество с ограниченной ответственностью "ЮГ П...
# 5298    Общество с ограниченной ответственностью "Проф...
# ...

# %%
df.loc[(df['adress'].str.contains ('Турусбекова')) & (df['director'].str.contains ('Лариса')) , ['name','adress','director']]
# Out:
#                                                      name              adress  \
# 20582   Общество с ограниченной ответственностью "Нект...
# 56450   Общество с ограниченной ответственностью "Пром...           ул.Достук
# 59419   Общество с ограниченной ответственностью "Теги...            ул.Жапар
# 63409   Общество с ограниченной ответственностью "Байзат"       Салиева 40г-2
# 69270   Общество с ограниченной ответственностью "Альф...      ул.Логвиненко
# 71212   Общество с ограниченной ответственностью "ВРЕМ...
# 76404   Филиал Общества с ограниченной ответственность...     ул. Депутатская
# 80891    Общество с ограниченной ответственностью "ЖАКИН"      ул.Тыныстанова
# 86107   Общество с ограниченной ответственностью "Мара...          ул. Алиева
# 89052   Общество с ограниченной ответственностью "БАЙН...        участок 1667
# 95065   Общество с ограниченной ответственностью "Паде...  ул. С. Атагелдиева
# ...

# %%
df.loc[(df['adress'].str.contains('Турусбекова')) & (df['director'].str.contains('Лариса')) , ['name','adress','director']]
# Out:
#                                                     name           adress  \
# 30374                                       ОсОО "Легат"      Турусбекова
# 58007  Общество с ограниченной ответственностью "ЮВ и...  ул. Турусбекова
#
#                         director
# 30374  Логинова Лариса Сергеевна
# 58007      Ли Лариса Евгеньевна
